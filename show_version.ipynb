# %%
import sys
import importlib

# %%
def show_version(package_names):
  print("Python version:", sys.version)
  print("\n Installed Packages:")
  print("-" * 40)
  for pkg in package_names:
    try:
      module = importlib.import_module(pkg)
      print(f"{pkg}: {module.__version__}")
    except ImportError:
      print(f"{pkg}: Not Installed")

# %%
show_version([
    "numpy",
    "matplotlib",
    "scipy",
    "pandas",
    "qutip"
])
# Out:
# Python version: 3.13.7 | packaged by Anaconda, Inc. | (main, Sep  9 2025, 19:54:37) [MSC v.1929 64 bit (AMD64)]
#
#  Installed Packages:
# ----------------------------------------
# numpy: 2.3.3
# matplotlib: 3.10.7
# scipy: 1.16.2
# pandas: 2.3.2
# qutip: 5.2.1
